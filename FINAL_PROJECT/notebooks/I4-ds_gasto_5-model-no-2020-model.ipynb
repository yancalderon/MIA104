# %% [markdown]
# ## Cargamos el dataset

# %%
#Importamos las librerias principales
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargamos dataset a utilizar
df_entrada = pd.read_csv("../data/ds_gasto_5.csv", sep=";")

# %%
df_entrada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627803 entries, 0 to 627802
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   ANIO                              627803 non-null  int64
#  1   NIVEL                             627803 non-null  int64
#  2   NIVEL_GOBIERNO                    627803 non-null  object
#  3   DPTO                              627803 non-null  int64
#  4   DEPARTAMENTO_EJECUTORA_NOMBRE     627803 non-null  object
#  5   FUNCION                           627803 non-null  int64
#  6   FUNCION_NOMBRE                    627803 non-null  object
#  7   PIA                               627803 non-null  int64
#  8   PIM                               627803 non-null  int64
#  9   DEVENGADO                         627803 non-null  float64
#  10  IP                                627803 non-null  float64
#  11  CAMBIO_GOBIERNO_NACIONAL          627803 non-null  int64
#  12  NRO_PRESIDENTES_X_ANO             627803 non-null  int64
#  13  FENOMENO_NINO                     627803 non-null  int64
#  14  PANDEMIA                          627803 non-null  int64
#  15  CAMBIO_GOBIERNO_REGIONAL_LOCAL    627803 non-null  int64
#  16  ELECCION_REGIONAL_LOCAL           627803 non-null  int64
#  17  TIPO_GOBIERNO_NACIONAL            627803 non-null  object
#  18  NRO_CONFLICTO_SOCIAL_X_ANO        627803 non-null  int64
#  19  INFLACION_ANUAL                   627803 non-null  float64
#  20  PROYECTO                          627803 non-null  int64
#  21  EJECUTORA                         627803 non-null  int64
#  22  PROYECTO_EDAD_NETA                627803 non-null  int64
#  23  PROYECTO_EDAD_BRUTA               627803 non-null  int64
#  24  IGEIP_EJECUCION                   627803 non-null  float64
#  25  P_INCO_AVG                        627803 non-null  float64
#  26  NEJE_PUNTAJEIRI                   627803 non-null  float64
#  27  NRO_EJECUTORAS_X_PROYECTO         627803 non-null  int64
#  28  NPRY_PUNTAJEIRI                   627803 non-null  float64
#  29  PUNTAJE_INCO_EJECUTORA            627803 non-null  float64
#  30  MONTO_VIABLE                      522452 non-null  float64
#  31  COSTO_ACTUALIZADO                 523620 non-null  float64
#  32  MODALIDAD_EJECUCION               627803 non-null  object
#  33  NRO_PROYECTOS_X_EJECUTORA_X_ANIO  627803 non-null  int64
#  34  AVANCE                            627803 non-null  float64
#  35  CLASE                             627803 non-null  int64
# dtypes: float64(11), int64(20), object(5)
# memory usage: 172.4+ MB

# %% [markdown]
# ### NULL values -> costo_actualizado, monto_viable

# %%
df_entrada.isnull().sum()
# Out:
# ANIO                                     0
# NIVEL                                    0
# NIVEL_GOBIERNO                           0
# DPTO                                     0
# DEPARTAMENTO_EJECUTORA_NOMBRE            0
# FUNCION                                  0
# FUNCION_NOMBRE                           0
# PIA                                      0
# PIM                                      0
# DEVENGADO                                0
# IP                                       0
# CAMBIO_GOBIERNO_NACIONAL                 0
# NRO_PRESIDENTES_X_ANO                    0
# FENOMENO_NINO                            0
# PANDEMIA                                 0
# CAMBIO_GOBIERNO_REGIONAL_LOCAL           0
# ELECCION_REGIONAL_LOCAL                  0
# TIPO_GOBIERNO_NACIONAL                   0
# NRO_CONFLICTO_SOCIAL_X_ANO               0
# INFLACION_ANUAL                          0
# PROYECTO                                 0
# EJECUTORA                                0
# PROYECTO_EDAD_NETA                       0
# PROYECTO_EDAD_BRUTA                      0
# IGEIP_EJECUCION                          0
# P_INCO_AVG                               0
# NEJE_PUNTAJEIRI                          0
# NRO_EJECUTORAS_X_PROYECTO                0
# NPRY_PUNTAJEIRI                          0
# PUNTAJE_INCO_EJECUTORA                   0
# MONTO_VIABLE                        105351
# COSTO_ACTUALIZADO                   104183
# MODALIDAD_EJECUCION                      0
# NRO_PROYECTOS_X_EJECUTORA_X_ANIO         0
# AVANCE                                   0
# CLASE                                    0
# dtype: int64

# %%
df_entrada_cleaned = df_entrada.dropna(subset=['MONTO_VIABLE'])

# %%
df_entrada_cleaned.isnull().sum()
# Out:
# ANIO                                0
# NIVEL                               0
# NIVEL_GOBIERNO                      0
# DPTO                                0
# DEPARTAMENTO_EJECUTORA_NOMBRE       0
# FUNCION                             0
# FUNCION_NOMBRE                      0
# PIA                                 0
# PIM                                 0
# DEVENGADO                           0
# IP                                  0
# CAMBIO_GOBIERNO_NACIONAL            0
# NRO_PRESIDENTES_X_ANO               0
# FENOMENO_NINO                       0
# PANDEMIA                            0
# CAMBIO_GOBIERNO_REGIONAL_LOCAL      0
# ELECCION_REGIONAL_LOCAL             0
# TIPO_GOBIERNO_NACIONAL              0
# NRO_CONFLICTO_SOCIAL_X_ANO          0
# INFLACION_ANUAL                     0
# PROYECTO                            0
# EJECUTORA                           0
# PROYECTO_EDAD_NETA                  0
# PROYECTO_EDAD_BRUTA                 0
# IGEIP_EJECUCION                     0
# P_INCO_AVG                          0
# NEJE_PUNTAJEIRI                     0
# NRO_EJECUTORAS_X_PROYECTO           0
# NPRY_PUNTAJEIRI                     0
# PUNTAJE_INCO_EJECUTORA              0
# MONTO_VIABLE                        0
# COSTO_ACTUALIZADO                   0
# MODALIDAD_EJECUCION                 0
# NRO_PROYECTOS_X_EJECUTORA_X_ANIO    0
# AVANCE                              0
# CLASE                               0
# dtype: int64

# %% [markdown]
# ### Filtrar una funcion -> Transporte

# %%
df_entrada_cleaned.ANIO.value_counts()
# Out:
# ANIO
# 2022    58731
# 2023    53849
# 2021    52400
# 2020    48395
# 2019    44624
# 2018    41171
# 2013    40872
# 2014    39482
# 2017    37393
# 2012    36975
# 2016    35761
# 2015    32799
# Name: count, dtype: int64

# %%
df_filtro_x_funcion = df_entrada_cleaned.query('ANIO != 2020')

# %%
df_filtro_x_funcion.ANIO.value_counts()
# Out:
# ANIO
# 2022    58731
# 2023    53849
# 2021    52400
# 2019    44624
# 2018    41171
# 2013    40872
# 2014    39482
# 2017    37393
# 2012    36975
# 2016    35761
# 2015    32799
# Name: count, dtype: int64

# %% [markdown]
# ## EXPLORACION

# %%
# Create a histogram for objective
plt.figure(figsize=(8, 5))
sns.histplot(df_filtro_x_funcion['CLASE'], bins=10, kde=False)
plt.xlabel('objective')
plt.ylabel('Frequency')
plt.title('Histogram of CLASE')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))  # Aumentamos el ancho para estirar horizontalmente
sns.countplot(
    data=df_entrada_cleaned,
    x='FUNCION_NOMBRE',
    hue='CLASE',
    #palette=sns.color_palette("tab10"),
    ax=ax
)
# Rotamos las etiquetas del eje x verticalmente
plt.xticks(rotation=90, ha='center')
# Ajustamos el diseño para que las etiquetas no se corten
#plt.tight_layout()
# Mostramos el gráfico
plt.show()

# %%
df_entrada_mayor_2021=df_entrada_cleaned.query('ANIO == 2019')
df_filtro_x_funcion.plot.scatter(x="NRO_PROYECTOS_X_EJECUTORA_X_ANIO", y="AVANCE", alpha=0.25)
#df_entrada.plot.scatter(x="PUNTAJE_INCO_EJECUTORA", y="AVANCE", alpha=0.1)
plt.show()
#IGEIP_EJECUCION
#NEJE_PUNTAJEIRI
#NRO_EJECUTORAS_X_PROYECTO
#P_INCO_AVG

# %% [markdown]
# # PREPARACION DE LOS DATOS

# %% [markdown]
# ## DROP

# %%
col_to_drop = [ 'ANIO'
            ,'NIVEL_GOBIERNO'
            ,'DEPARTAMENTO_EJECUTORA_NOMBRE'
            ,'FUNCION_NOMBRE'
            ,'PIA'
            ,'DEVENGADO'
            ,'PROYECTO'
            ,'EJECUTORA'
            ,'AVANCE' 
            #,'CLASE'
            ,'FENOMENO_NINO' # IG muy bajo
            ,'CAMBIO_GOBIERNO_NACIONAL' # IG muy bajo
            ,'P_INCO_AVG' # Incluido en PUNTAJE_INCO_EJECUTORA
            ,'NEJE_PUNTAJEIRI' # Incluido en NPRY_PUNTAJEIRI
            ]
               
df_entrada_drop = df_filtro_x_funcion.drop(col_to_drop, axis='columns', inplace=False)

# %%
df_entrada_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 474057 entries, 0 to 627802
# Data columns (total 23 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   NIVEL                             474057 non-null  int64
#  1   DPTO                              474057 non-null  int64
#  2   FUNCION                           474057 non-null  int64
#  3   PIM                               474057 non-null  int64
#  4   IP                                474057 non-null  float64
#  5   NRO_PRESIDENTES_X_ANO             474057 non-null  int64
#  6   PANDEMIA                          474057 non-null  int64
#  7   CAMBIO_GOBIERNO_REGIONAL_LOCAL    474057 non-null  int64
#  8   ELECCION_REGIONAL_LOCAL           474057 non-null  int64
#  9   TIPO_GOBIERNO_NACIONAL            474057 non-null  object
#  10  NRO_CONFLICTO_SOCIAL_X_ANO        474057 non-null  int64
#  11  INFLACION_ANUAL                   474057 non-null  float64
#  12  PROYECTO_EDAD_NETA                474057 non-null  int64
#  13  PROYECTO_EDAD_BRUTA               474057 non-null  int64
#  14  IGEIP_EJECUCION                   474057 non-null  float64
#  15  NRO_EJECUTORAS_X_PROYECTO         474057 non-null  int64
#  16  NPRY_PUNTAJEIRI                   474057 non-null  float64
#  17  PUNTAJE_INCO_EJECUTORA            474057 non-null  float64
#  18  MONTO_VIABLE                      474057 non-null  float64
#  19  COSTO_ACTUALIZADO                 474057 non-null  float64
#  20  MODALIDAD_EJECUCION               474057 non-null  object
#  21  NRO_PROYECTOS_X_EJECUTORA_X_ANIO  474057 non-null  int64
#  22  CLASE                             474057 non-null  int64
# dtypes: float64(7), int64(14), object(2)
# memory usage: 86.8+ MB

# %% [markdown]
# ## ONE HOT

# %%
# Aplicar one-hot encoding a 'columna1'
columns_to_one_hot_encode = ['NIVEL', 'TIPO_GOBIERNO_NACIONAL', 'DPTO', 'FUNCION', 'MODALIDAD_EJECUCION']
df_one_hot = pd.get_dummies(df_entrada_drop, columns=columns_to_one_hot_encode, dtype=int)

# %%
(
    df_one_hot.rename(columns={'TIPO_GOBIERNO_NACIONAL_Centro derecha': 'tgn_centro_derecha',
                                'TIPO_GOBIERNO_NACIONAL_Centro izquierda': 'tgn_centro_izquierda',
                                'TIPO_GOBIERNO_NACIONAL_Izquierda': 'tgn_izquierda',
                                        }, inplace=True)
)

# %%
df_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 474057 entries, 0 to 627802
# Data columns (total 77 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   PIM                                  474057 non-null  int64
#  1   IP                                   474057 non-null  float64
#  2   NRO_PRESIDENTES_X_ANO                474057 non-null  int64
#  3   PANDEMIA                             474057 non-null  int64
#  4   CAMBIO_GOBIERNO_REGIONAL_LOCAL       474057 non-null  int64
#  5   ELECCION_REGIONAL_LOCAL              474057 non-null  int64
#  6   NRO_CONFLICTO_SOCIAL_X_ANO           474057 non-null  int64
#  7   INFLACION_ANUAL                      474057 non-null  float64
#  8   PROYECTO_EDAD_NETA                   474057 non-null  int64
#  9   PROYECTO_EDAD_BRUTA                  474057 non-null  int64
#  10  IGEIP_EJECUCION                      474057 non-null  float64
#  11  NRO_EJECUTORAS_X_PROYECTO            474057 non-null  int64
#  12  NPRY_PUNTAJEIRI                      474057 non-null  float64
#  13  PUNTAJE_INCO_EJECUTORA               474057 non-null  float64
#  14  MONTO_VIABLE                         474057 non-null  float64
#  15  COSTO_ACTUALIZADO                    474057 non-null  float64
#  16  NRO_PROYECTOS_X_EJECUTORA_X_ANIO     474057 non-null  int64
#  17  CLASE                                474057 non-null  int64
#  18  NIVEL_1                              474057 non-null  int64
#  19  NIVEL_2                              474057 non-null  int64
#  20  NIVEL_3                              474057 non-null  int64
#  21  tgn_centro_derecha                   474057 non-null  int64
#  22  tgn_centro_izquierda                 474057 non-null  int64
#  23  tgn_izquierda                        474057 non-null  int64
#  24  DPTO_1                               474057 non-null  int64
#  25  DPTO_2                               474057 non-null  int64
#  26  DPTO_3                               474057 non-null  int64
#  27  DPTO_4                               474057 non-null  int64
#  28  DPTO_5                               474057 non-null  int64
#  29  DPTO_6                               474057 non-null  int64
#  30  DPTO_7                               474057 non-null  int64
#  31  DPTO_8                               474057 non-null  int64
#  32  DPTO_9                               474057 non-null  int64
#  33  DPTO_10                              474057 non-null  int64
#  34  DPTO_11                              474057 non-null  int64
#  35  DPTO_12                              474057 non-null  int64
#  36  DPTO_13                              474057 non-null  int64
#  37  DPTO_14                              474057 non-null  int64
#  38  DPTO_15                              474057 non-null  int64
#  39  DPTO_16                              474057 non-null  int64
#  40  DPTO_17                              474057 non-null  int64
#  41  DPTO_18                              474057 non-null  int64
#  42  DPTO_19                              474057 non-null  int64
#  43  DPTO_20                              474057 non-null  int64
#  44  DPTO_21                              474057 non-null  int64
#  45  DPTO_22                              474057 non-null  int64
#  46  DPTO_23                              474057 non-null  int64
#  47  DPTO_24                              474057 non-null  int64
#  48  DPTO_25                              474057 non-null  int64
#  49  FUNCION_2                            474057 non-null  int64
#  50  FUNCION_3                            474057 non-null  int64
#  51  FUNCION_4                            474057 non-null  int64
#  52  FUNCION_5                            474057 non-null  int64
#  53  FUNCION_6                            474057 non-null  int64
#  54  FUNCION_7                            474057 non-null  int64
#  55  FUNCION_8                            474057 non-null  int64
#  56  FUNCION_9                            474057 non-null  int64
#  57  FUNCION_10                           474057 non-null  int64
#  58  FUNCION_11                           474057 non-null  int64
#  59  FUNCION_12                           474057 non-null  int64
#  60  FUNCION_13                           474057 non-null  int64
#  61  FUNCION_14                           474057 non-null  int64
#  62  FUNCION_15                           474057 non-null  int64
#  63  FUNCION_16                           474057 non-null  int64
#  64  FUNCION_17                           474057 non-null  int64
#  65  FUNCION_18                           474057 non-null  int64
#  66  FUNCION_19                           474057 non-null  int64
#  67  FUNCION_20                           474057 non-null  int64
#  68  FUNCION_21                           474057 non-null  int64
#  69  FUNCION_22                           474057 non-null  int64
#  70  FUNCION_23                           474057 non-null  int64
#  71  FUNCION_24                           474057 non-null  int64
#  72  FUNCION_25                           474057 non-null  int64
#  73  MODALIDAD_EJECUCION_DIRECTA          474057 non-null  int64
#  74  MODALIDAD_EJECUCION_INDIRECTA        474057 non-null  int64
#  75  MODALIDAD_EJECUCION_MIXTA            474057 non-null  int64
#  76  MODALIDAD_EJECUCION_SIN_INFORMACION  474057 non-null  int64
# dtypes: float64(7), int64(70)
# memory usage: 282.1 MB

# %%
df_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 474057 entries, 0 to 627802
# Data columns (total 77 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   PIM                                  474057 non-null  int64
#  1   IP                                   474057 non-null  float64
#  2   NRO_PRESIDENTES_X_ANO                474057 non-null  int64
#  3   PANDEMIA                             474057 non-null  int64
#  4   CAMBIO_GOBIERNO_REGIONAL_LOCAL       474057 non-null  int64
#  5   ELECCION_REGIONAL_LOCAL              474057 non-null  int64
#  6   NRO_CONFLICTO_SOCIAL_X_ANO           474057 non-null  int64
#  7   INFLACION_ANUAL                      474057 non-null  float64
#  8   PROYECTO_EDAD_NETA                   474057 non-null  int64
#  9   PROYECTO_EDAD_BRUTA                  474057 non-null  int64
#  10  IGEIP_EJECUCION                      474057 non-null  float64
#  11  NRO_EJECUTORAS_X_PROYECTO            474057 non-null  int64
#  12  NPRY_PUNTAJEIRI                      474057 non-null  float64
#  13  PUNTAJE_INCO_EJECUTORA               474057 non-null  float64
#  14  MONTO_VIABLE                         474057 non-null  float64
#  15  COSTO_ACTUALIZADO                    474057 non-null  float64
#  16  NRO_PROYECTOS_X_EJECUTORA_X_ANIO     474057 non-null  int64
#  17  CLASE                                474057 non-null  int64
#  18  NIVEL_1                              474057 non-null  int64
#  19  NIVEL_2                              474057 non-null  int64
#  20  NIVEL_3                              474057 non-null  int64
#  21  tgn_centro_derecha                   474057 non-null  int64
#  22  tgn_centro_izquierda                 474057 non-null  int64
#  23  tgn_izquierda                        474057 non-null  int64
#  24  DPTO_1                               474057 non-null  int64
#  25  DPTO_2                               474057 non-null  int64
#  26  DPTO_3                               474057 non-null  int64
#  27  DPTO_4                               474057 non-null  int64
#  28  DPTO_5                               474057 non-null  int64
#  29  DPTO_6                               474057 non-null  int64
#  30  DPTO_7                               474057 non-null  int64
#  31  DPTO_8                               474057 non-null  int64
#  32  DPTO_9                               474057 non-null  int64
#  33  DPTO_10                              474057 non-null  int64
#  34  DPTO_11                              474057 non-null  int64
#  35  DPTO_12                              474057 non-null  int64
#  36  DPTO_13                              474057 non-null  int64
#  37  DPTO_14                              474057 non-null  int64
#  38  DPTO_15                              474057 non-null  int64
#  39  DPTO_16                              474057 non-null  int64
#  40  DPTO_17                              474057 non-null  int64
#  41  DPTO_18                              474057 non-null  int64
#  42  DPTO_19                              474057 non-null  int64
#  43  DPTO_20                              474057 non-null  int64
#  44  DPTO_21                              474057 non-null  int64
#  45  DPTO_22                              474057 non-null  int64
#  46  DPTO_23                              474057 non-null  int64
#  47  DPTO_24                              474057 non-null  int64
#  48  DPTO_25                              474057 non-null  int64
#  49  FUNCION_2                            474057 non-null  int64
#  50  FUNCION_3                            474057 non-null  int64
#  51  FUNCION_4                            474057 non-null  int64
#  52  FUNCION_5                            474057 non-null  int64
#  53  FUNCION_6                            474057 non-null  int64
#  54  FUNCION_7                            474057 non-null  int64
#  55  FUNCION_8                            474057 non-null  int64
#  56  FUNCION_9                            474057 non-null  int64
#  57  FUNCION_10                           474057 non-null  int64
#  58  FUNCION_11                           474057 non-null  int64
#  59  FUNCION_12                           474057 non-null  int64
#  60  FUNCION_13                           474057 non-null  int64
#  61  FUNCION_14                           474057 non-null  int64
#  62  FUNCION_15                           474057 non-null  int64
#  63  FUNCION_16                           474057 non-null  int64
#  64  FUNCION_17                           474057 non-null  int64
#  65  FUNCION_18                           474057 non-null  int64
#  66  FUNCION_19                           474057 non-null  int64
#  67  FUNCION_20                           474057 non-null  int64
#  68  FUNCION_21                           474057 non-null  int64
#  69  FUNCION_22                           474057 non-null  int64
#  70  FUNCION_23                           474057 non-null  int64
#  71  FUNCION_24                           474057 non-null  int64
#  72  FUNCION_25                           474057 non-null  int64
#  73  MODALIDAD_EJECUCION_DIRECTA          474057 non-null  int64
#  74  MODALIDAD_EJECUCION_INDIRECTA        474057 non-null  int64
#  75  MODALIDAD_EJECUCION_MIXTA            474057 non-null  int64
#  76  MODALIDAD_EJECUCION_SIN_INFORMACION  474057 non-null  int64
# dtypes: float64(7), int64(70)
# memory usage: 282.1 MB

# %% [markdown]
# ## X e y

# %%
X = df_one_hot.drop(['CLASE'], axis=1)
y = df_one_hot['CLASE'].values

# %% [markdown]
# ## Split train and test

# %%
from sklearn.model_selection import train_test_split
(X_train, X_test, y_train, y_test) = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # MODELING

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from time import time
# 2. Función para entrenar y evaluar modelos
def train_and_evaluate(model, X_train, X_test, y_train, y_test):
    start_time = time()
    model.fit(X_train, y_train)
    train_time = time() - start_time
    
    start_time = time()
    y_pred = model.predict(X_test)
    predict_time = time() - start_time
    
    accuracy = accuracy_score(y_test, y_pred)
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Training time: {train_time:.2f} seconds")
    print(f"Prediction time: {predict_time:.2f} seconds")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier

# 4. Random Forest
print("\nTraining Random Forest model...")
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
train_and_evaluate(rf_model, X_train, X_test, y_train, y_test)
# Out:
# Training Random Forest model...
# Accuracy: 0.7123
# Training time: 28.23 seconds
# Prediction time: 1.49 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.53      0.59     55736
#            1       0.73      0.83      0.78     86482
#
#     accuracy                           0.71    142218
#    macro avg       0.70      0.68      0.68    142218
# weighted avg       0.71      0.71      0.70    142218
#
#
# Confusion Matrix:
# [[29461 26275]
#  [14636 71846]]

# %%
# 5. Optimización de hiperparámetros para Random Forest
print("\nOptimizing Random Forest hyperparameters...")
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_random = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                               param_distributions=param_dist,
                               n_iter=10, cv=3, verbose=2, random_state=42, n_jobs=-1)

rf_random.fit(X_train, y_train)

print("Best parameters:", rf_random.best_params_)
print("\nEvaluating optimized Random Forest model...")
train_and_evaluate(rf_random.best_estimator_, X_train, X_test, y_train, y_test)
# Out:
# Optimizing Random Forest hyperparameters...
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 30}
#
# Evaluating optimized Random Forest model...

# %% [markdown]
# # StandardScaler

# %% [markdown]
# ## RobustScaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
# Crear el objeto RobustScaler
scaler = RobustScaler()

# Ajustar el scaler a los datos de entrenamiento y transformar
X_train_scaled = scaler.fit_transform(X_train)

# Transformar los datos de prueba
X_test_scaled = scaler.transform(X_test)

# %%
# Convertir los resultados a DataFrames si es necesario
X_train_rs = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_rs = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
result = model.fit(X_train_scaled, y_train)
# Out:
# c:\ws\scm\github\mia\MIA104\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score
prediction_test = model.predict(X_test_scaled)
print(accuracy_score(y_test, prediction_test))
# Out:
# 0.6237747683134343

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# 4. Random Forest
print("\nTraining Random Forest model...")
rf_model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
train_and_evaluate(rf_model, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Training Random Forest model...
# Accuracy: 0.7128
# Training time: 27.85 seconds
# Prediction time: 1.63 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.53      0.59     55736
#            1       0.73      0.83      0.78     86482
#
#     accuracy                           0.71    142218
#    macro avg       0.70      0.68      0.68    142218
# weighted avg       0.71      0.71      0.71    142218
#
#
# Confusion Matrix:
# [[29513 26223]
#  [14628 71854]]

# %%
feature_importances = rf_model.feature_importances_

importances_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': feature_importances
})  

importances_df = importances_df.sort_values('importance', ascending=False)

# %%
importances_df.head(20)
# Out:
#                                 feature  importance
# 0                                   PIM    0.119781
# 15                    COSTO_ACTUALIZADO    0.104128
# 14                         MONTO_VIABLE    0.103163
# 12                      NPRY_PUNTAJEIRI    0.099891
# 16     NRO_PROYECTOS_X_EJECUTORA_X_ANIO    0.083108
# 13               PUNTAJE_INCO_EJECUTORA    0.075566
# 9                   PROYECTO_EDAD_BRUTA    0.042015
# 1                                    IP    0.039659
# 8                    PROYECTO_EDAD_NETA    0.039348
# 10                      IGEIP_EJECUCION    0.031045
# 6            NRO_CONFLICTO_SOCIAL_X_ANO    0.017060
# 7                       INFLACION_ANUAL    0.015883
# 61                           FUNCION_15    0.012885
# 68                           FUNCION_22    0.010344
# 64                           FUNCION_18    0.010264
# 73        MODALIDAD_EJECUCION_INDIRECTA    0.008702
# 56                           FUNCION_10    0.008236
# 75  MODALIDAD_EJECUCION_SIN_INFORMACION    0.008144
# 67                           FUNCION_21    0.007702
# 72          MODALIDAD_EJECUCION_DIRECTA    0.006651

# %% [markdown]
# #### Optimización

# %%
# 5. Optimización de hiperparámetros para Random Forest
print("\nOptimizing Random Forest hyperparameters...")
param_dist = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_random = RandomizedSearchCV(estimator=RandomForestClassifier(random_state=42),
                               param_distributions=param_dist,
                               n_iter=10, cv=3, verbose=2, random_state=42, n_jobs=-1)

rf_random.fit(X_train_scaled, y_train)

print("Best parameters:", rf_random.best_params_)
print("\nEvaluating optimized Random Forest model...")
train_and_evaluate(rf_random.best_estimator_, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Optimizing Random Forest hyperparameters...
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': None}
#
# Evaluating optimized Random Forest model...
# Accuracy: 0.7163
# Training time: 278.43 seconds
# Prediction time: 16.58 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.52      0.59     55736
#            1       0.73      0.84      0.78     86482
#
#     accuracy                           0.72    142218
#    macro avg       0.71      0.68      0.69    142218
# weighted avg       0.71      0.72      0.71    142218
#
#
# Confusion Matrix:
# [[29170 26566]
#  [13788 72694]]

# %% [markdown]
# ## GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier
# 4. Random Forest
print("\nTraining GBM model...")
gbm_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
train_and_evaluate(gbm_model, X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Training GBM model...
# Accuracy: 0.6456
# Training time: 122.85 seconds
# Prediction time: 0.31 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.24      0.35     55736
#            1       0.65      0.91      0.76     86482
#
#     accuracy                           0.65    142218
#    macro avg       0.64      0.57      0.55    142218
# weighted avg       0.64      0.65      0.60    142218
#
#
# Confusion Matrix:
# [[13337 42399]
#  [ 8002 78480]]
